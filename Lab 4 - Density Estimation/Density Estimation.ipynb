# %% [markdown]
# # Density Estimation Techniques
# In this lab, you will implement the density estimation techniques we studied in the lecture.
#
# ## Lab Instructions:
# 1. Read the explanation above each requirement very well
# 2. Read the requirement very well before jumping into the code.
# 3. Some requirements have essay questions in them, make sure you do NOT miss them.
# 4. PLEASE Read the hints! They are clear and made to help you complete the requirement as fast as you should
#
# ## About the Lab
# This lab consists of one requirement: [Requirement 1](#Requirement-1) where you implement one of the density estimation methods.
#
# - Refer to the slides whenever you need an equation or a formula.
# - In this lab, you are free to choose your bump function. However, higher accuracies will get a higher grade. <br/>**You will need to justify your choice of that bump function, write that in your own words, do not copy from your colleagues**
# - Feel free to use code from Lab 3.

# %% [markdown]
# ------------------
# ## Density Estimation
#
# ### Recap
#
# In the previous lab, we were introduced to the problem of classification of multivariate data, and we applied Bayes classifier to classify these points.
#
# The Bayes classification rule depends mainly on the class-conditional probability (also known as the class density or class distribution). An accurate method to calculate this distribution is crucial for improving the performance of the classifier.
#
# We built our classifier based on the assumption that this data is multivariate Gaussian random distribution, and we estimated the mean and covariance of this distribution. Finally, a test vector x is classified as (i.e. assigned) the class that maximizes the posterior probability:
#
# $P(C_i|x_{test}) = \frac{P(x_{test}|C_i) * P(C_i)}{P(x_{test})}$
#
# Classification of $x_{test}$ = $argmax_{i} P\big(C_i|x_{test}\big)$ = $argmax_{i} P(x|C_i) * P(C_i)$
#
# * $P(C_i|x_{test})$: Posterior probability
# * $P(x|C_i)$: Class-conditional probability (or distribution)
# * $P(C_i)$: Class apriori probability
#
# **Note that** $P(C_i|x_{test}) \neq P(x_{test}|C_i) * P(C_i)$. Instead,  $P(C_i|x_{test}) = \frac{P(x_{test}|C_i) * P(C_i)}{P(x_{test})}$. However, when we compare multiple classes, the denominator $P(x_{test})$ is independent of the class $i$ and can be regarded as normalizing factor.
#
#
# Where $P(x|C_i)$ is given by the multivariate Gaussian random distribution:
#
# $P(x|C_i) = \mathcal{N}(x; \mu_i, \Sigma_i) = \frac{1}{(2\pi)^{\frac{N}{2}}|\Sigma_i|^{\frac{1}{2}}} exp\big(\frac{-1}{2}(x-\mu_i)^T\Sigma^{-1}_{i}(x-\mu_i)\big)$
#
#
#  ### In this lab
# We will drop off the assumption that $P(x|C_i)$ is drawn out of a Gaussian distribution with mean $\mu$ and covariance $\Sigma$. The distribution is not necessarily Gaussian, yet we will still apply Bayes classifier to classify between data points by assigning each point to the class that maximizes its posterior probability as usual.
#
# #### What will change in Bayes classifier under the new assumption?
# We will answer that for you! $P(x|C_i)$ is no longer equal to the Gaussian distribution as shown
# in the previous equation i.e. we can’t use the Gaussian formula to substitute for $P(x|C_i)$.
#
# #### How will we figure out the unknown distribution (also known as likelihood function)?
# We will answer that for you too! There are three ways for doing so:
#
#     1. Histogram Analysis.
#     2. Naïve Estimator.
#     3. Parzen Window Density Estimator.
#
# All these techniques aim to estimate a density function $P(x|C_i)$ for the training points, and hence you can use the density function to apply Bayes classifier and classify your test points.
# *Refer to the slides to get a brief about these techniques.*

# %% [markdown]
# ## Requirement 1
#
# You are given files **data.csv**, **test_data.csv**, and  **test_data_true.csv**.
#
# **The first file** contains a list of one-dimensional data points and their corresponding classes. The data points were drawn of the
#  distribution shown in Figure 1 (NOTE: It will be your task to estimate this distribution).
#
# ![Screen%20Shot%202020-11-21%20at%2001.01.52-2.png](attachment:Screen%20Shot%202020-11-21%20at%2001.01.52-2.png)
#
# As shown in Figure 1, the points belonging to class 1 were drawn out of the distribution in blue,
# whereas the points belonging to class 2 were drawn out of the distribution in red.
#
# After applying Parzen Window Density Estimator and plotting the estimated distribution for
# both classes, you should observe a similar distribution for each class to the corresponding
# distribution shown in Figure 1.
#
# The format of data files is shown in the following table:
#
# ||Class|Value|
# |-|-|-|
# |Point#1| 1| 5.34|
# |Point#2| 2| 2.73|
# |Point#3| 2| -1.832|
#
# **The second file** contains test points without the associated classes.
#
# The true values for test
# points are found in *test_data_true.csv*.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **The first step** is to read and import the training data, test data and the true values for the test data,
# found in the given files respectively.

# %%
def read_data():
    data = None
    # TODO 1: Read the file 'data.csv' into the variable data.
    csvData = pd.read_csv('data.csv', sep=",", header=None)
    # Convert the matrix data into numpy array and make sure that the values in data is float and not strings.
    data = np.asarray(csvData, dtype=np.float32)
    # Hint: You already implemented it in Lab 3.
    # Hint: use data = np.asarray(data)
    # Note: data contains both the training data together with labelled classes.
    return data

# %%
def read_test_data():
    test_data = None
    test_data_true = None
    # TODO 2: Read the file 'test_data.csv' and 'test_data_true.csv' into the variables test_data and test_data_true.
    csvTestData = pd.read_csv('test_data.csv', sep=",", header=None)
    csvTestDataTrue = pd.read_csv('test_data_true.csv', sep=",", header=None)
    # Convert the matrix data into numpy arrays and make sure that the values in data is float and not strings.
    test_data = np.asarray(csvTestData, dtype=np.float32)
    test_data_true = np.asarray(csvTestDataTrue, dtype=np.float32)
    # Hint: You already implemented it in Lab 3.
    # Note: test_data contains the unlabelled test class.
    # Note: test_data_true contains the actual classes of the test instances, which you will compare
    #       against your predicted classes.
    return test_data, test_data_true

# %%
data = read_data()
test_data, test_data_true = read_test_data()

# %% [markdown]
# **The second step** is to choose a suitable bump function (Parzen window), and find the optimal value of `h`
# for the bump function for each class.
#
# First, fill in the function `calculate_h_optimal()`. Pass the convenient parameters.

# %%
# Note: Pass the suitable parameters
def calculate_h_optimal(stdDev, N, M):
    # TODO 3: Calculate the optimal value for the bandwidth (h) of Parzen window (or the bump function you are going
    # to compute). Pass the suitable parameters. 
    # Hint: Refer to the slides to find out the equation of computing h optimal and know which parameters you should pass.
    h = stdDev * (4 / ((N+2)*M)) ** (1 / (N+4))
    return h

# %% [markdown]
# Second, implement the bump function (i.e. Parzen window). You should compute
# the bump function for any x, given a point p and an optimal value for h.
#
# Y = F(x), where x represents the domain of the function or equivalently some
# values to compute the bump function at, y represents the output of the bump
# function and F represents the bump function.
#
# **Notes:** You should vectorise this (i.e. your function should work if x were a single data point or a vector of M data points).

# %%
def bump_function(point, x, h):
    # TODO 4: Implement the bump function phi(x) at point p with bandwidth h. Note that x can be a scalar or a vector.
    # NOTE: Your solution should be vectorized.
    x = (np.array(x) - point) * h
    f = np.exp(-(x**2) / (2 * h**2)) / (np.sqrt(2*np.pi) * h)
    return f

# %% [markdown]
# **Question 1** What are the criteria of choosing bump function?

# %%
'''
    Your Answer:
    
    It's necessary for the bump function to be continuous and smooth so that all other points contribute
    to the density value at a certain point even slightly.
    
    The bump function integrates to 1 to ensure normalization for the density function
    
    Symmetric to produce a symmetric density estimate and avoid skewness
    
    Computationally efficient to reduce the overall cost of the kernel density estimator
    
    We need to obtain a non-negative density estimate so the bump function should also be non-negative
    
    Robust to outliers and other forms of noise in the data
    
    Should be suitable for the given dataset as different bump functions could be better for certain datasets
'''
# Out:
# "\n    Your Answer:\n    \n    It's necessary for the bump function to be continuous and smooth so that all other points contribute\n    to the density value at a certain point even slightly.\n    \n    The bump function integrates to 1 to ensure normalization for the density function\n    \n    Symmetric to produce a symmetric density estimate and avoid skewness\n    \n    Computationally efficient to reduce the overall cost of the kernel density estimator\n    \n    We need to obtain a non-negative density estimate so the bump function should also be non-negative\n    \n    Robust to outliers and other forms of noise in the data\n    \n    Suitable for the giveen dataset\n"

# %% [markdown]
# **Question 2** Justify why you choose that as your bump function. Do you expect it to enhance accuracy? Why?
#
# Write everything you would like to say

# %%
'''
    Your Answer:
    
    The gaussian kernel is most commonly a popular choice when choosing a bump function as it satisfies many
    of the above mentioned criteria
    
    Its continuity and smoothness ensures that the density estimate is most accurate
    
    It's symmetric, integrates to 1, and efficient in computation. The effect of h is noticable in the gaussian function
    as well.. so choosing it as the optimal enhances accuracy.
    
    The gaussian function is also non-negative which ensures a positive density estimate
    
    Extends from negative infinity to infinity across the x-axis
    
    Its shape shows that at the point where the bump function is placed, this point represents the peak of the bump function
    and as we go further left or right of the same curve, the value decreases exponentially which is logical. Why? Because the
    farther the point, the lower its contribution to the estimate of the density at the original point.
'''
# Out:
# "\n    Your Answer:\n    \n    The gaussian kernel is most commonly a popular choice when choosing a bump function as it satisfies many\n    of the above mentioned criteria\n    \n    Its continuity and smoothness ensures that the density estimate is most accurate\n    \n    It's symmetric, integrates to 1, and efficient in computation. The effect of h is noticable in the gaussian function\n    as well so choosing it as the optimal enhances accuracy.\n"

# %% [markdown]
# **At this point,** you need to iterate over the training points and apply the bump
# function for every training point.\
# The density estimate will be the accumulation (i.e. the sum) of the output of these bump functions.
#
# We first need to generate the x vector which represents the possible values for the one
# dimensional feature we have. You can find the minimum and maximum possible values for x among the training data, and generate a range of points which will represent your one-dimensional axis.
#
#                             x = np.linspace(min_x, max_x, number_of_axis_points)
#
# Here, `min_x` represents the minimum value for the feature x, `max_x` represents the
# maximum value for the feature x, and `number_of_axis_points` represents the
# resolution of the scale (or how many points should be included between these two
# limits).

# %%
# TODO 5: Construct x-axis that will be used in density estimation.
X = np.array(data[:, 1])
Y = np.array(data[:, 0])
min_x = min(X)
max_x = max(X)
number_of_axis_points = 10000
x = np.linspace(min_x, max_x, number_of_axis_points)

# %% [markdown]
# Now we need to compute the desnsities for each class. Remember that the density estimate represents `P(x|Ci)`
#
# We start by computing h_optimal for each class we have:

# %%
# TODO 6: Calculate the optimal h for each class. 
# (Warning: Do not use for loops. Use vectorization, broadcasting and masking).
X_C1 = X[Y == 1]
X_C2 = X[Y == 2]
h1 = calculate_h_optimal(np.std(X_C1), 1, len(X_C1))
h2 = calculate_h_optimal(np.std(X_C2), 1, len(X_C2))

# %% [markdown]
# We then use these h_optimals to calculate the density functions:

# %%
# TODO 7: Calculate the probability density function p(x|C1) and p(x|C2) for each value on the constructed x-axis
def calcDensity(X, x_range, h):
    return np.sum(np.array([bump_function(p, x_range, h) for p in X]), axis=0)/(len(X))

pxgivenC1 = calcDensity(X_C1, x, h1) # Class 1
pxgivenC2 = calcDensity(X_C2, x, h2) # Class 2

# %% [markdown]
# Now we need to visualize how well are we estimating the densities.\
# Let's plot the density estimates for the two classes that we computed in **ONE PLOT** with **DIFFERENT
# COLORS.** This is an ordinary plot.
#
# **Check your plot result**:\
# Is it similar to Figure 1? If yes, proceed to question 5. If no, unfortunately you have
# done something wrong. Think: Do you need another bump function? Do you need more points?
#
# **FAQ:** What do you mean by two classes in one plot with different colors?\
# Answer: The two classes are overlaid together in one plot (such as Figure 1) with
# different colors (red and blue). We can’t be any more specific :")

# %%
# plot the estimated densities
# TODO 8: Plot the two densities P(x|C1) and P(x|C2) on the same plot. use plt.plot(..)
plt.plot(x, pxgivenC1, 'b')
plt.plot(x, pxgivenC2, 'r')
plt.show()

# %% [markdown]
# It’s time to classify the test points. You know what to do already! Given the points in
# the test file, it’s required to classify each point whether it belongs to class 1 or 2 by
# applying Bayes classifier. Report the accuracy of your classifier by comparing with
# the true values found in the third file.
#
# Hint: It’s not as easy as it looks like, there’s a trick here. Be creative in your solution.
# Solutions may differ in this part, and this may lead to varying accuracies between
# students.\
# *May the odds be in your favor and you get the highest accuracy!*

# %%
# TODO 9: Calculate the aprior probabilities p(C1) and p(C2).
pc1 = len(Y[Y == 1]) / len(Y)
pc2 = len(Y[Y == 2]) / len(Y)

# %%
# TODO 10: Calculate the posterior probabilities p(C1|x) and p(C2|x) for all values in x.
px = pxgivenC1 * pc1 + pxgivenC2 * pc2
pc1GivenX = pxgivenC1 * pc1 / px
pc2GivenX = pxgivenC2 * pc2 / px

# %%
def find_nearest(array, value):
    '''
    This function finds which element in array is equal to value. If not found, it returns the nearest (or closest)
    element in the array to value.
    :param array: An array of values to search in.
    :param value: A value to select from the array.
    :return: The index of the found element in the array. If not found, it returns the index of the closest element.
    '''
    ## DO NOT Change Code ##
    array = np.asarray(array)
    index = (np.abs(array - value)).argmin()
    return index

# %%
# TODO 11: Compute the accuracy of your classifier.
accuracy = 0
results = []
for idx, point in enumerate(test_data):
    closestIndex = find_nearest(x, point)
    if (pc1GivenX[closestIndex] > pc2GivenX[closestIndex]):
        classification = 1
    else:
        classification = 2
    results.append(classification)
    print("for point:", point, "the classification: ", classification)
# Out:
# for point: [11.2331705] the classification:  2
# for point: [17.05956] the classification:  2
# for point: [20.] the classification:  2
# for point: [-3.1319356] the classification:  1
# for point: [8.80189] the classification:  2
# for point: [6.] the classification:  1
# for point: [0.14068925] the classification:  1
# for point: [3.0081732] the classification:  1
# for point: [5.] the classification:  1
# for point: [1.4576863] the classification:  1
# for point: [23.] the classification:  2
# for point: [2.478728] the classification:  1
# for point: [-2.8986206] the classification:  1
# for point: [2.8864336] the classification:  1
# for point: [10.985523] the classification:  2
# for point: [10.501951] the classification:  2
# for point: [21.092712] the classification:  2
# for point: [0.75791645] the classification:  1
# for point: [-4.012684] the classification:  1
# for point: [-2.8380728] the classification:  1
# for point: [13.212368] the classification:  2
# for point: [18.] the classification:  2
# for point: [4.0535326] the classification:  1
# for point: [2.9602077] the classification:  1
# for point: [0.58233446] the classification:  1
# for point: [12.579486] the classification:  2
# for point: [-2.7491589] the classification:  1
# for point: [6.] the classification:  1
# for point: [0.82682675] the classification:  1
# for point: [19.] the classification:  2
# for point: [24.] the classification:  2
# for point: [17.] the classification:  2
# for point: [-2.0958443] the classification:  1
# for point: [0.25830442] the classification:  1
# for point: [12.407845] the classification:  2
# for point: [1.0516503] the classification:  1
# for point: [7.] the classification:  1
# for point: [11.451796] the classification:  2
# for point: [2.164882] the classification:  1
# for point: [4.0254207] the classification:  1
# for point: [8.054614] the classification:  2
# for point: [14.0505085] the classification:  2
# for point: [8.] the classification:  2
# for point: [24.] the classification:  2
# for point: [12.688408] the classification:  2
# for point: [11.15646] the classification:  2
# for point: [12.269106] the classification:  2
# for point: [22.] the classification:  2
# for point: [26.] the classification:  2
# for point: [12.873489] the classification:  2
# for point: [0.20484082] the classification:  1
# for point: [10.298742] the classification:  2
# for point: [16.542597] the classification:  2
# for point: [11.536177] the classification:  2
# for point: [-3.033647] the classification:  1
# for point: [8.] the classification:  2
# for point: [7.] the classification:  1
# for point: [1.2040913] the classification:  1
# for point: [12.6172285] the classification:  2
# for point: [10.871138] the classification:  2
# for point: [6.] the classification:  1
# for point: [12.690284] the classification:  2
# for point: [10.] the classification:  2
# for point: [12.558889] the classification:  2
# for point: [23.] the classification:  2
# for point: [-0.08566497] the classification:  1
# for point: [16.] the classification:  2
# for point: [7.269739] the classification:  2
# for point: [3.2795837] the classification:  1
# for point: [3.] the classification:  1
# for point: [-3.0825984] the classification:  1
# for point: [17.] the classification:  2
# for point: [8.] the classification:  2
# for point: [0.70514226] the classification:  1
# for point: [0.54934096] the classification:  1
# for point: [-2.3034651] the classification:  1
# for point: [0.00269114] the classification:  1
# for point: [0.30951908] the classification:  1
# for point: [17.] the classification:  2
# for point: [11.029452] the classification:  2
# for point: [11.151494] the classification:  2
# for point: [-1.06088] the classification:  1
# for point: [3.7830825] the classification:  1
# for point: [1.5711486] the classification:  1
# for point: [2.] the classification:  1
# for point: [18.] the classification:  2
# for point: [10.183548] the classification:  2
# for point: [3.] the classification:  1
# for point: [-0.1242808] the classification:  1
# for point: [-0.69722825] the classification:  1
# for point: [-2.073903] the classification:  1
# for point: [-1.0087575] the classification:  1
# for point: [18.] the classification:  2
# for point: [10.141746] the classification:  2
# for point: [2.9265707] the classification:  1
# for point: [0.44461328] the classification:  1
# for point: [11.334057] the classification:  2
# for point: [11.70364] the classification:  2
# for point: [4.] the classification:  1
# for point: [-2.3002534] the classification:  1
# for point: [7.3481503] the classification:  2
# for point: [21.] the classification:  2
# for point: [10.] the classification:  2
# for point: [7.662973] the classification:  2
# for point: [11.6336775] the classification:  2
# for point: [0.58892775] the classification:  1
# for point: [-3.615071] the classification:  1
# for point: [27.] the classification:  2
# for point: [22.] the classification:  2
# for point: [8.074886] the classification:  2
# for point: [23.] the classification:  2
# for point: [-4.082808] the classification:  1
# for point: [9.434116] the classification:  2
# for point: [3.] the classification:  1
# for point: [10.127232] the classification:  2
# for point: [14.927108] the classification:  2
# for point: [14.506055] the classification:  2
# for point: [14.] the classification:  2
# for point: [12.540564] the classification:  2
# for point: [-2.4790957] the classification:  1
# for point: [5.] the classification:  1
# for point: [16.027401] the classification:  2
# for point: [18.] the classification:  2
# for point: [21.] the classification:  2
# for point: [6.] the classification:  1
# for point: [5.961865] the classification:  1
# for point: [-3.623066] the classification:  1
# for point: [11.218885] the classification:  2
# for point: [3.0833957] the classification:  1
# for point: [12.585875] the classification:  2
# for point: [4.19271] the classification:  1
# for point: [6.71448] the classification:  1
# for point: [10.669408] the classification:  2
# for point: [-4.2185154] the classification:  1
# for point: [5.] the classification:  1
# for point: [1.2606314] the classification:  1
# for point: [11.62685] the classification:  2
# for point: [3.] the classification:  1
# for point: [12.192386] the classification:  2
# for point: [6.] the classification:  1
# for point: [3.] the classification:  1
# for point: [10.] the classification:  2
# for point: [0.2558917] the classification:  1
# for point: [7.028267] the classification:  1
# for point: [17.] the classification:  2
# for point: [5.143196] the classification:  1
# for point: [18.] the classification:  2
# for point: [6.027961] the classification:  1
# for point: [-3.3413785] the classification:  1
# for point: [7.] the classification:  1
# for point: [0.7539322] the classification:  1
# for point: [0.24945848] the classification:  1
# for point: [1.0507838] the classification:  1
# for point: [-0.48441628] the classification:  1
# for point: [11.298414] the classification:  2
# for point: [4.] the classification:  1
# for point: [7.] the classification:  1
# for point: [1.7255954] the classification:  1
# for point: [-0.1794073] the classification:  1
# for point: [5.] the classification:  1
# for point: [8.039216] the classification:  2
# for point: [24.028664] the classification:  2
# for point: [19.] the classification:  2
# for point: [1.6589906] the classification:  1
# for point: [-0.45788017] the classification:  1
# for point: [1.1065887] the classification:  1
# for point: [1.3551024] the classification:  1
# for point: [-0.8138645] the classification:  1
# for point: [8.814108] the classification:  2
# for point: [16.332167] the classification:  2
# for point: [0.4595173] the classification:  1
# for point: [9.933106] the classification:  2
# for point: [-3.6874144] the classification:  1
# for point: [-4.476485] the classification:  1
# for point: [7.] the classification:  1
# for point: [8.311269] the classification:  2
# for point: [10.055191] the classification:  2
# for point: [0.43523654] the classification:  1
# for point: [2.1330023] the classification:  1
# for point: [-5.029887] the classification:  1
# for point: [13.] the classification:  2
# for point: [12.857477] the classification:  2
# for point: [5.2817726] the classification:  1
# for point: [5.] the classification:  1
# for point: [7.334849] the classification:  2
# for point: [12.718671] the classification:  2
# for point: [21.] the classification:  2
# for point: [21.] the classification:  2
# for point: [9.160272] the classification:  2
# for point: [6.] the classification:  1
# for point: [4.626021] the classification:  1
# for point: [0.12559417] the classification:  1
# for point: [14.034348] the classification:  2
# for point: [6.] the classification:  1
# for point: [8.] the classification:  2
# for point: [14.382033] the classification:  2
# for point: [9.462202] the classification:  2
# for point: [-3.3183222] the classification:  1
# for point: [0.26347068] the classification:  1
# for point: [2.919776] the classification:  1
# for point: [-0.9989825] the classification:  1
# for point: [2.3222053] the classification:  1
# for point: [12.3221855] the classification:  2
# for point: [-2.8658497] the classification:  1
# for point: [1.2229583] the classification:  1
# for point: [15.210711] the classification:  2
# for point: [3.] the classification:  1
# for point: [2.6039107] the classification:  1
# for point: [11.015433] the classification:  2
# for point: [8.796778] the classification:  2
# for point: [9.965308] the classification:  2
# for point: [-2.2681115] the classification:  1
# for point: [1.9644009] the classification:  1
# for point: [24.] the classification:  2
# for point: [12.302862] the classification:  2
# for point: [-1.30755] the classification:  1
# for point: [-1.7357235] the classification:  1
# for point: [-3.3061953] the classification:  1
# for point: [3.5783165] the classification:  1
# for point: [-0.16584155] the classification:  1
# for point: [-0.3129477] the classification:  1
# for point: [28.] the classification:  2
# for point: [4.] the classification:  1
# for point: [7.6562195] the classification:  2
# for point: [11.496856] the classification:  2
# for point: [12.061777] the classification:  2
# for point: [-0.69137204] the classification:  1
# for point: [0.0823093] the classification:  1
# for point: [5.541595] the classification:  1
# for point: [11.75688] the classification:  2
# for point: [-0.94813657] the classification:  1
# for point: [-3.7585108] the classification:  1
# for point: [0.7156661] the classification:  1
# for point: [0.7311346] the classification:  1
# for point: [0.3066048] the classification:  1
# for point: [-3.9718738] the classification:  1
# for point: [10.549363] the classification:  2
# for point: [16.] the classification:  2
# for point: [0.3432395] the classification:  1
# for point: [15.513088] the classification:  2
# for point: [-0.66220665] the classification:  1
# for point: [15.] the classification:  2
# for point: [12.99859] the classification:  2
# for point: [11.042171] the classification:  2
# for point: [23.] the classification:  2
# for point: [12.879789] the classification:  2
# for point: [3.] the classification:  1
# for point: [14.216621] the classification:  2
# for point: [7.438325] the classification:  2
# for point: [2.2058973] the classification:  1
# for point: [0.32997596] the classification:  1
# for point: [11.079872] the classification:  2
# for point: [10.021733] the classification:  2
# for point: [2.38062] the classification:  1
# for point: [3.33303] the classification:  1
# for point: [11.899945] the classification:  2
# for point: [1.0114225] the classification:  1
# for point: [-1.9159529] the classification:  1
# for point: [3.8586452] the classification:  1
# for point: [0.28307262] the classification:  1
# for point: [7.683665] the classification:  2
# for point: [0.20875098] the classification:  1
# for point: [18.] the classification:  2
# for point: [0.85843414] the classification:  1
# for point: [22.] the classification:  2
# for point: [11.767512] the classification:  2
# for point: [7.0587115] the classification:  2
# for point: [15.502335] the classification:  2
# for point: [11.472043] the classification:  2
# for point: [9.] the classification:  2
# for point: [-2.3579922] the classification:  1
# for point: [14.131291] the classification:  2
# for point: [0.18528956] the classification:  1
# for point: [12.741474] the classification:  2
# for point: [7.1130967] the classification:  2
# for point: [10.525608] the classification:  2
# for point: [12.405895] the classification:  2
# for point: [1.1081964] the classification:  1
# for point: [19.] the classification:  2
# for point: [6.569898] the classification:  1
# for point: [11.219811] the classification:  2
# for point: [12.5268755] the classification:  2
# for point: [4.] the classification:  1
# for point: [4.312817] the classification:  1
# for point: [12.08184] the classification:  2
# for point: [11.] the classification:  2
# for point: [0.04872458] the classification:  1
# for point: [5.736533] the classification:  1
# for point: [6.3395925] the classification:  1
# for point: [4.] the classification:  1
# for point: [-2.6003025] the classification:  1
# for point: [11.307179] the classification:  2
# for point: [19.966589] the classification:  2
# for point: [-0.9864784] the classification:  1
# for point: [13.181154] the classification:  2
# for point: [12.45555] the classification:  2
# for point: [8.33344] the classification:  2
# for point: [23.] the classification:  2
# for point: [15.035709] the classification:  2
# for point: [9.894376] the classification:  2

# %%
accuracy = (np.sum(results == test_data_true[:, 0]) / len(test_data_true)) * 100
print("Accuracy = ", accuracy, "%")
# Out:
# Accuracy =  92.0 %
